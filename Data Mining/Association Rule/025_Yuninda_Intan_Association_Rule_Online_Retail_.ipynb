# %% [markdown]
# > Yuninda Intan
#
# > 21051214025
#
# > Sistem Informasi 2021 A

# %% [markdown]
# #Import Data

# %%
import pandas as pd
import numpy as np
import io

import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import mlxtend as ml

import warnings
warnings.filterwarnings("ignore", message="should_run_async will not call transform_cell automatically", category=DeprecationWarning)

# %%
# Loading the dataset
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
data = pd.read_excel('/content/drive/MyDrive/dataset/Online Retail.xlsx')
print("Jumlah Fitur: ", data.shape[1])

data
# Out:
# Mounted at /content/drive
# Jumlah Fitur:  8
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# #Preprocessing

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print ("Jumlah data hilang pada setiap kolom: ")
print (data.isnull().sum())

data_cleaned = data.dropna()
print (f"Jumlah baris setelah hapus missing value: {len(data_cleaned)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Jumlah data hilang pada setiap kolom:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# Jumlah baris setelah hapus missing value: 406829

# %%
data.duplicated().sum()
# Out:
# 5268

# %%
dataclean = data.drop_duplicates()
dataclean.duplicated().sum()
# Out:
# 0

# %%
dataclean.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
dataclean.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
dataclean['Description'].value_counts().to_dict()
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2357,
#  'REGENCY CAKESTAND 3 TIER': 2189,
#  'JUMBO BAG RED RETROSPOT': 2156,
#  'PARTY BUNTING': 1720,
#  'LUNCH BAG RED RETROSPOT': 1625,
#  'ASSORTED COLOUR BIRD ORNAMENT': 1488,
#  'SET OF 3 CAKE TINS PANTRY DESIGN ': 1465,
#  'PACK OF 72 RETROSPOT CAKE CASES': 1367,
#  'LUNCH BAG  BLACK SKULL.': 1323,
#  'NATURAL SLATE HEART CHALKBOARD ': 1272,
#  'POSTAGE': 1252,
#  'JUMBO BAG PINK POLKADOT': 1245,
#  'HEART OF WICKER SMALL': 1230,
#  'JAM MAKING SET WITH JARS': 1221,
#  'JUMBO STORAGE BAG SUKI': 1211,
#  "PAPER CHAIN KIT 50'S CHRISTMAS ": 1194,
#  'JUMBO SHOPPER VINTAGE RED PAISLEY': 1192,
#  'LUNCH BAG CARS BLUE': 1185,
#  'JAM MAKING SET PRINTED': 1177,
#  'LUNCH BAG SPACEBOY DESIGN ': 1177,
#  'RECIPE BOX PANTRY YELLOW DESIGN': 1173,
#  'SPOTTY BUNTING': 1168,
#  'ROSES REGENCY TEACUP AND SAUCER ': 1128,
#  'WOODEN PICTURE FRAME WHITE FINISH': 1124,
#  'LUNCH BAG PINK POLKADOT': 1121,
#  'LUNCH BAG SUKI DESIGN ': 1121,
#  'SET OF 4 PANTRY JELLY MOULDS': 1099,
#  'ALARM CLOCK BAKELIKE RED ': 1092,
#  'LUNCH BAG APPLE DESIGN': 1066,
#  'GREEN REGENCY TEACUP AND SAUCER': 1066,
#  'VICTORIAN GLASS HANGING T-LIGHT': 1066,
#  'RED RETROSPOT CHARLOTTE BAG': 1065,
#  'LUNCH BAG WOODLAND': 1050,
#  'RABBIT NIGHT LIGHT': 1032,
#  'ALARM CLOCK BAKELIKE GREEN': 1012,
#  'SET/20 RED RETROSPOT PAPER NAPKINS ': 1008,
#  'JUMBO BAG APPLES': 1007,
#  'WOODEN FRAME ANTIQUE WHITE ': 995,
#  'RETROSPOT TEA SET CERAMIC 11 PC ': 980,
#  '6 RIBBONS RUSTIC CHARM': 976,
#  'BAKING SET 9 PIECE RETROSPOT ': 965,
#  'JUMBO  BAG BAROQUE BLACK WHITE': 957,
#  'HEART OF WICKER LARGE': 953,
#  'VINTAGE SNAP CARDS': 939,
#  'GARDENERS KNEELING PAD KEEP CALM ': 931,
#  'SET/5 RED RETROSPOT LID GLASS BOWLS': 926,
#  'JUMBO BAG ALPHABET': 925,
#  'SET OF 3 REGENCY CAKE TINS': 913,
#  'SPACEBOY LUNCH BOX ': 913,
#  'REX CASH+CARRY JUMBO SHOPPER': 912,
#  'CHARLOTTE BAG SUKI DESIGN': 902,
#  'JUMBO BAG VINTAGE LEAF': 892,
#  'PACK OF 60 PINK PAISLEY CAKE CASES': 886,
#  'JUMBO BAG PINK VINTAGE PAISLEY': 884,
#  'CHOCOLATE HOT WATER BOTTLE': 881,
#  'JUMBO BAG WOODLAND ANIMALS': 878,
#  'DOLLY GIRL LUNCH BOX': 868,
#  'PLEASE ONE PERSON METAL SIGN': 867,
#  'RED TOADSTOOL LED NIGHT LIGHT': 867,
#  'POPCORN HOLDER': 861,
#  'SET OF 6 SPICE TINS PANTRY DESIGN': 859,
#  '60 TEATIME FAIRY CAKE CASES': 852,
#  'WOODLAND CHARLOTTE BAG': 850,
#  'PAPER CHAIN KIT VINTAGE CHRISTMAS': 843,
#  'JUMBO BAG STRAWBERRY': 842,
#  'PAPER BUNTING RETROSPOT': 810,
#  'ALARM CLOCK BAKELIKE PINK': 808,
#  'HOT WATER BOTTLE KEEP CALM': 804,
#  'PINK REGENCY TEACUP AND SAUCER': 804,
#  'HOME BUILDING BLOCK WORD': 791,
#  'SCOTTIE DOG HOT WATER BOTTLE': 788,
#  'CLOTHES PEGS RETROSPOT PACK 24 ': 786,
#  'CHARLOTTE BAG PINK POLKADOT': 774,
#  'GARDENERS KNEELING PAD CUP OF TEA ': 773,
#  'LUNCH BAG ALPHABET DESIGN': 769,
#  'GIN + TONIC DIET METAL SIGN': 769,
#  'RED HANGING HEART T-LIGHT HOLDER': 766,
#  'STRAWBERRY CERAMIC TRINKET BOX': 765,
#  'HANGING HEART JAR T-LIGHT HOLDER': 763,
#  'RECYCLING BAG RETROSPOT ': 755,
#  'ROUND SNACK BOXES SET OF4 WOODLAND ': 750,
#  'LUNCH BOX I LOVE LONDON': 740,
#  'DOORMAT KEEP CALM AND COME IN': 739,
#  'COOK WITH WINE METAL SIGN ': 739,
#  'STRAWBERRY CHARLOTTE BAG': 738,
#  'JUMBO BAG VINTAGE DOILY ': 731,
#  "JUMBO BAG 50'S CHRISTMAS ": 729,
#  'IVORY KITCHEN SCALES': 725,
#  'GUMBALL COAT RACK': 719,
#  'PLASTERS IN TIN WOODLAND ANIMALS': 719,
#  'JUMBO STORAGE BAG SKULLS': 717,
#  'ANTIQUE SILVER T-LIGHT GLASS': 715,
#  'DOTCOM POSTAGE': 709,
#  'DOORMAT RED RETROSPOT': 705,
#  'SET OF 3 BUTTERFLY COOKIE CUTTERS': 702,
#  'JUMBO BAG SPACEBOY DESIGN': 698,
#  'LUNCH BAG DOLLY GIRL DESIGN': 698,
#  'PACK OF 20 NAPKINS PANTRY DESIGN': 698,
#  'SET OF 3 HEART COOKIE CUTTERS': 696,
#  'WOOD BLACK BOARD ANT WHITE FINISH': 696,
#  'PLASTERS IN TIN SPACEBOY': 689,
#  'GINGERBREAD MAN COOKIE CUTTER': 684,
#  'HAND OVER THE CHOCOLATE   SIGN ': 682,
#  'LUNCH BAG VINTAGE LEAF DESIGN': 681,
#  'HAND WARMER OWL DESIGN': 677,
#  'CHILLI LIGHTS': 676,
#  'RED  HARMONICA IN BOX ': 673,
#  'JUMBO BAG SCANDINAVIAN BLUE PAISLEY': 672,
#  'PACK OF 72 SKULL CAKE CASES': 672,
#  'JUMBO BAG OWLS': 668,
#  'HOT WATER BOTTLE I AM SO POORLY': 668,
#  'HOMEMADE JAM SCENTED CANDLES': 654,
#  'HOT WATER BOTTLE TEA AND SYMPATHY': 652,
#  'SMALL WHITE HEART OF WICKER': 648,
#  'RETROSPOT HEART HOT WATER BOTTLE': 648,
#  'SET OF 60 PANTRY DESIGN CAKE CASES ': 646,
#  'BATHROOM METAL SIGN': 639,
#  'LOVE BUILDING BLOCK WORD': 636,
#  '60 CAKE CASES VINTAGE CHRISTMAS': 636,
#  '72 SWEETHEART FAIRY CAKE CASES': 634,
#  'COLOUR GLASS T-LIGHT HOLDER HANGING': 634,
#  'SET OF 20 VINTAGE CHRISTMAS NAPKINS': 631,
#  'HOT BATHS METAL SIGN': 631,
#  'DOORMAT UNION FLAG': 625,
#  'PINK CREAM FELT CRAFT TRINKET BOX ': 624,
#  'TRADITIONAL KNITTING NANCY': 623,
#  'LUNCH BAG VINTAGE DOILY ': 619,
#  'PACK OF 60 DINOSAUR CAKE CASES': 618,
#  'PAPER CHAIN KIT RETROSPOT': 616,
#  'VINTAGE HEADS AND TAILS CARD GAME ': 615,
#  'BLUE HARMONICA IN BOX ': 612,
#  'HANGING HEART ZINC T-LIGHT HOLDER': 609,
#  'SMALL POPCORN HOLDER': 607,
#  'JUMBO BAG PEARS': 604,
#  'DOORMAT NEW ENGLAND': 604,
#  'WOODEN BOX OF DOMINOES': 602,
#  'ROUND SNACK BOXES SET OF 4 FRUITS ': 601,
#  'BOX OF 24 COCKTAIL PARASOLS': 598,
#  'DOORMAT HEARTS': 596,
#  'CHARLOTTE BAG APPLES DESIGN': 594,
#  'STRAWBERRY LUNCH BOX WITH CUTLERY': 593,
#  'WOOD 2 DRAWER CABINET WHITE FINISH': 588,
#  'PLASTERS IN TIN CIRCUS PARADE ': 587,
#  'GREY HEART HOT WATER BOTTLE': 586,
#  'ALARM CLOCK BAKELIKE IVORY': 585,
#  'RED RETROSPOT SHOPPER BAG': 583,
#  'RED RETROSPOT CAKE STAND': 583,
#  'LARGE WHITE HEART OF WICKER': 582,
#  'SMALL GLASS HEART TRINKET POT': 582,
#  'PLASTERS IN TIN VINTAGE PAISLEY ': 580,
#  'PLASTERS IN TIN SKULLS': 578,
#  'RED KITCHEN SCALES': 570,
#  'Manual': 567,
#  'HAND WARMER BIRD DESIGN': 567,
#  'HAND WARMER SCOTTY DOG DESIGN': 567,
#  'CHILDRENS APRON SPACEBOY DESIGN': 566,
#  'FELTCRAFT 6 FLOWER FRIENDS': 562,
#  'SET OF 12 FAIRY CAKE BAKING CASES': 559,
#  'WOODEN HEART CHRISTMAS SCANDINAVIAN': 556,
#  'LOVEBIRD HANGING DECORATION WHITE ': 556,
#  'CHRISTMAS CRAFT LITTLE FRIENDS': 556,
#  'CREAM SWEETHEART MINI CHEST': 549,
#  'TRAVEL CARD WALLET KEEP CALM': 549,
#  'EDWARDIAN PARASOL NATURAL': 549,
#  'ZINC METAL HEART DECORATION': 547,
#  'POTTERING IN THE SHED METAL SIGN': 544,
#  'RED RETROSPOT PICNIC BAG': 544,
#  'WORLD WAR 2 GLIDERS ASSTD DESIGNS': 541,
#  'SWEETHEART CERAMIC TRINKET BOX': 540,
#  'SMALL DOLLY MIX DESIGN ORANGE BOWL': 535,
#  'WOODEN STAR CHRISTMAS SCANDINAVIAN': 533,
#  'SUKI  SHOULDER BAG': 532,
#  'JUMBO BAG TOYS ': 532,
#  'SET/6 RED SPOTTY PAPER PLATES': 532,
#  'CREAM HEART CARD HOLDER': 531,
#  'PINK BLUE FELT CRAFT TRINKET BOX': 530,
#  'PACK OF 60 SPACEBOY CAKE CASES': 529,
#  'SPACEBOY BIRTHDAY CARD': 529,
#  'PLASTERS IN TIN STRONGMAN': 528,
#  'PACK OF 12 LONDON TISSUES ': 526,
#  'ENAMEL FLOWER JUG CREAM': 525,
#  'SET OF 20 KIDS COOKIE CUTTERS': 524,
#  'PHOTO FRAME CORNICE': 524,
#  'ASSORTED COLOURS SILK FAN': 523,
#  'JUMBO BAG DOILEY PATTERNS': 521,
#  'WHITE SKULL HOT WATER BOTTLE ': 515,
#  'SET OF 72 PINK HEART PAPER DOILIES': 513,
#  'SINGLE HEART ZINC T-LIGHT HOLDER': 509,
#  'NATURAL SLATE CHALKBOARD LARGE ': 509,
#  'FAWN BLUE HOT WATER BOTTLE': 508,
#  'SET OF TEA COFFEE SUGAR TINS PANTRY': 506,
#  'DOORMAT FANCY FONT HOME SWEET HOME': 505,
#  'RED RETROSPOT PEG BAG': 504,
#  'NO SINGING METAL SIGN': 504,
#  'METAL 4 HOOK HANGER FRENCH CHATEAU': 504,
#  'FELTCRAFT BUTTERFLY HEARTS': 503,
#  'LUNCH BAG DOILEY PATTERN ': 501,
#  'HAND WARMER UNION JACK': 500,
#  'PANTRY MAGNETIC  SHOPPING LIST': 499,
#  'PINK FAIRY CAKE CHILDRENS APRON': 497,
#  '4 TRADITIONAL SPINNING TOPS': 493,
#  'LUNCH BOX WITH CUTLERY RETROSPOT ': 493,
#  'JUMBO BAG VINTAGE CHRISTMAS ': 493,
#  'RECIPE BOX RETROSPOT ': 492,
#  'SET/3 RED GINGHAM ROSE STORAGE BOX': 491,
#  'VINTAGE UNION JACK BUNTING': 489,
#  'LOVE HOT WATER BOTTLE': 488,
#  'DOORMAT SPOTTY HOME SWEET HOME': 484,
#  'SMALL HEART MEASURING SPOONS': 483,
#  'LADIES & GENTLEMEN METAL SIGN': 483,
#  'BAKING SET SPACEBOY DESIGN': 483,
#  'TOY TIDY PINK POLKADOT': 480,
#  'FELTCRAFT CUSHION OWL': 480,
#  'SET OF 3 WOODEN HEART DECORATIONS': 479,
#  'PARTY METAL SIGN ': 477,
#  'CHOCOLATE THIS WAY METAL SIGN': 476,
#  '3 STRIPEY MICE FELTCRAFT': 476,
#  'TRAVEL SEWING KIT': 476,
#  'TEA TIME PARTY BUNTING': 475,
#  'PICNIC BASKET WICKER SMALL': 474,
#  'ENAMEL BREAD BIN CREAM': 471,
#  'ZINC FOLKART SLEIGH BELLS': 471,
#  'ALARM CLOCK BAKELIKE ORANGE': 470,
#  'KNITTED UNION FLAG HOT WATER BOTTLE': 470,
#  'RED DINER WALL CLOCK': 469,
#  'ROTATING SILVER ANGELS T-LIGHT HLDR': 468,
#  'CHRISTMAS CRAFT TREE TOP ANGEL': 468,
#  'PICNIC BASKET WICKER LARGE': 464,
#  'MEMO BOARD RETROSPOT  DESIGN': 464,
#  'RED RETROSPOT OVEN GLOVE ': 462,
#  "YOU'RE CONFUSING ME METAL SIGN ": 461,
#  'SCANDINAVIAN REDS RIBBONS': 459,
#  'SET OF 72 RETROSPOT PAPER  DOILIES': 458,
#  'REGENCY TEA PLATE ROSES ': 457,
#  'SMALL MARSHMALLOWS PINK BOWL': 457,
#  'BEWARE OF THE CAT METAL SIGN ': 456,
#  'CHARLOTTE BAG VINTAGE ALPHABET ': 456,
#  'FELTCRAFT PRINCESS CHARLOTTE DOLL': 456,
#  'SET OF 12 MINI LOAF BAKING CASES': 455,
#  'RED RETROSPOT BOWL': 454,
#  'JUMBO BAG DOLLY GIRL DESIGN': 453,
#  'SCANDINAVIAN PAISLEY PICNIC BAG': 453,
#  'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN': 451,
#  'RED STRIPE CERAMIC DRAWER KNOB': 451,
#  'SET OF 6 SOLDIER SKITTLES': 451,
#  'DOORMAT WELCOME TO OUR HOME': 450,
#  'PACK OF 12 TRADITIONAL CRAYONS': 448,
#  'ALARM CLOCK BAKELIKE CHOCOLATE': 448,
#  '60 CAKE CASES DOLLY GIRL DESIGN': 447,
#  'CARD BILLBOARD FONT': 446,
#  'WHITE WOOD GARDEN PLANT LADDER': 446,
#  'WOODEN SCHOOL COLOURING SET': 445,
#  'PAPER CHAIN KIT EMPIRE': 445,
#  'SET 3 RETROSPOT TEA,COFFEE,SUGAR': 444,
#  'BLUE STRIPE CERAMIC DRAWER KNOB': 444,
#  'RED WOOLLY HOTTIE WHITE HEART.': 444,
#  "POPPY'S PLAYHOUSE KITCHEN": 443,
#  'AREA PATROLLED METAL SIGN': 443,
#  'TOILET SIGN OCCUPIED OR VACANT': 443,
#  'VINTAGE PAISLEY STATIONERY SET': 442,
#  'TRADITIONAL WOODEN SKIPPING ROPE': 439,
#  'SET OF 6 RIBBONS VINTAGE CHRISTMAS': 436,
#  'SET/6 RED SPOTTY PAPER CUPS': 435,
#  'IVORY DINER WALL CLOCK': 434,
#  'REGENCY TEAPOT ROSES ': 434,
#  'SET OF 3 NOTEBOOKS IN PARCEL': 432,
#  'SOLDIERS EGG CUP ': 431,
#  'CHILDRENS CUTLERY POLKADOT PINK': 429,
#  'PACK OF 12 HEARTS DESIGN TISSUES ': 429,
#  'FLORAL FOLK STATIONERY SET': 428,
#  "POPPY'S PLAYHOUSE BEDROOM ": 428,
#  'VINTAGE DOILY TRAVEL SEWING KIT': 427,
#  'SET OF 60 I LOVE LONDON CAKE CASES ': 426,
#  'VINTAGE CREAM DOG FOOD CONTAINER': 426,
#  'NATURAL SLATE RECTANGLE CHALKBOARD': 426,
#  'CHARLOTTE BAG DOLLY GIRL DESIGN': 423,
#  'WHITE SPOT RED CERAMIC DRAWER KNOB': 422,
#  'PINK VINTAGE PAISLEY PICNIC BAG': 421,
#  'WOOD S/3 CABINET ANT WHITE FINISH': 421,
#  'SKULL LUNCH BOX WITH CUTLERY ': 420,
#  'GINGHAM HEART DECORATION': 420,
#  'TRADITIONAL WOODEN CATCH CUP GAME ': 420,
#  'TRAVEL CARD WALLET VINTAGE TICKET': 419,
#  'METAL SIGN TAKE IT OR LEAVE IT ': 419,
#  'STRAWBERRY SHOPPER BAG': 419,
#  'FELTCRAFT PRINCESS LOLA DOLL': 418,
#  'RIBBON REEL STRIPES DESIGN ': 417,
#  "BOX OF 6 MINI 50'S CRACKERS": 417,
#  'WICKER STAR ': 415,
#  'DOORMAT ENGLISH ROSE ': 414,
#  'SET 6 SCHOOL MILK BOTTLES IN CRATE': 414,
#  'CHICK GREY HOT WATER BOTTLE': 413,
#  'SKULL SHOULDER BAG': 413,
#  'FOUR HOOK  WHITE LOVEBIRDS': 412,
#  'WOODEN UNION JACK BUNTING': 412,
#  'HAND WARMER RED LOVE HEART': 412,
#  'TOILET METAL SIGN': 411,
#  'PACK OF 6 BIRDY GIFT TAGS': 411,
#  'VINTAGE CHRISTMAS BUNTING': 410,
#  'RED SPOTTY BISCUIT TIN': 409,
#  'CANDLEHOLDER PINK HANGING HEART': 409,
#  'AIRLINE BAG VINTAGE TOKYO 78': 408,
#  'CIRCUS PARADE LUNCH BOX ': 408,
#  'PINK HAPPY BIRTHDAY BUNTING': 407,
#  'SWEETHEART CAKESTAND 3 TIER': 406,
#  'BREAD BIN DINER STYLE IVORY': 406,
#  'CERAMIC STRAWBERRY CAKE MONEY BANK': 404,
#  'RED RETROSPOT CUP': 400,
#  'PACK OF 60 MUSHROOM CAKE CASES': 400,
#  'SET/2 RED RETROSPOT TEA TOWELS ': 399,
#  'VINTAGE SNAKES & LADDERS': 398,
#  '3 HOOK PHOTO SHELF ANTIQUE WHITE': 398,
#  'ENAMEL MEASURING JUG CREAM': 394,
#  'BLUE HAPPY BIRTHDAY BUNTING': 393,
#  'FELTCRAFT CUSHION RABBIT': 392,
#  'ASSORTED COLOUR MINI CASES': 391,
#  'SET OF 10 LED DOLLY LIGHTS': 391,
#  'TRADITIONAL MODELLING CLAY': 390,
#  'OPEN CLOSED METAL SIGN': 390,
#  'RED RETROSPOT MINI CASES': 390,
#  'MINI PAINT SET VINTAGE ': 390,
#  'SET OF 60 VINTAGE LEAF CAKE CASES ': 389,
#  'FAMILY ALBUM WHITE PICTURE FRAME': 389,
#  'BOX OF 6 MINI VINTAGE CRACKERS': 389,
#  'HAND WARMER RED RETROSPOT': 389,
#  'SET OF 6 TEA TIME BAKING CASES': 388,
#  'CHRISTMAS CRAFT WHITE FAIRY ': 388,
#  '3 PIECE SPACEBOY COOKIE CUTTER SET': 388,
#  'EDWARDIAN PARASOL BLACK': 388,
#  'REGENCY TEA PLATE GREEN ': 388,
#  'PANTRY WASHING UP BRUSH': 388,
#  'SET 7 BABUSHKA NESTING BOXES': 387,
#  'SET/10 RED POLKADOT PARTY CANDLES': 386,
#  'PACK OF 20 NAPKINS RED APPLES': 385,
#  'BINGO SET': 385,
#  'RED SPOT CERAMIC DRAWER KNOB': 384,
#  'BLUE SPOT CERAMIC DRAWER KNOB': 383,
#  'HEART IVORY TRELLIS SMALL': 383,
#  'SET 2 PANTRY DESIGN TEA TOWELS': 382,
#  'ENGLISH ROSE HOT WATER BOTTLE': 382,
#  'BLACK RECORD COVER FRAME': 381,
#  'HAND WARMER BABUSHKA DESIGN': 380,
#  'LARGE HEART MEASURING SPOONS': 379,
#  'WHITE SPOT BLUE CERAMIC DRAWER KNOB': 378,
#  'PAINTED METAL PEARS ASSORTED': 378,
#  'KEY FOB , SHED': 376,
#  'RED RETROSPOT UMBRELLA': 375,
#  'MINT KITCHEN SCALES': 375,
#  'SET 12 KIDS COLOUR  CHALK STICKS': 375,
#  'COLOURING PENCILS BROWN TUBE': 375,
#  'SWEETHEART RECIPE BOOK STAND': 374,
#  'SAVE THE PLANET MUG': 373,
#  'BLUE DINER WALL CLOCK': 372,
#  'CHILDRENS CUTLERY SPACEBOY ': 372,
#  'TREASURE TIN GYMKHANA DESIGN': 371,
#  'MULTI COLOUR SILVER T-LIGHT HOLDER': 371,
#  'MODERN FLORAL STATIONERY SET': 370,
#  'SET OF 4 KNICK KNACK TINS DOILY ': 370,
#  '12 PENCILS SMALL TUBE RED RETROSPOT': 370,
#  "I'M ON HOLIDAY METAL SIGN": 370,
#  'JINGLE BELL HEART DECORATION': 370,
#  'RECIPE BOX BLUE SKETCHBOOK DESIGN': 370,
#  'DOORMAT FAIRY CAKE': 369,
#  'RECORD FRAME 7" SINGLE SIZE ': 369,
#  'RETROSPOT CHILDRENS APRON': 368,
#  'WASHROOM METAL SIGN': 368,
#  'PACK OF 12 SUKI TISSUES ': 367,
#  'TEA PARTY BIRTHDAY CARD': 367,
#  '12 PENCIL SMALL TUBE WOODLAND': 367,
#  'CHILDRENS APRON APPLES DESIGN': 367,
#  'SET 12 RETRO WHITE CHALK STICKS': 366,
#  'SET OF 36 PAISLEY FLOWER DOILIES': 366,
#  '12 PENCILS SMALL TUBE SKULL': 366,
#  'HOME SWEET HOME MUG': 365,
#  'HANGING METAL HEART LANTERN': 365,
#  'TRADITIONAL CHRISTMAS RIBBONS': 365,
#  'REVOLVER WOODEN RULER ': 364,
#  'WOODEN ROUNDERS GARDEN SET ': 363,
#  'JAM JAR WITH PINK LID': 363,
#  'SET OF 6 SNACK LOAF BAKING CASES': 362,
#  'RED RETROSPOT SMALL MILK JUG': 362,
#  'PICTURE DOMINOES': 362,
#  'ANTIQUE SILVER TEA GLASS ENGRAVED': 362,
#  'TEA BAG PLATE RED RETROSPOT': 362,
#  "ROLL WRAP 50'S CHRISTMAS": 361,
#  'CERAMIC HEART FAIRY CAKE MONEY BANK': 360,
#  'HANGING JAM JAR T-LIGHT HOLDER': 359,
#  'HEART DECORATION RUSTIC HANGING ': 358,
#  'T-LIGHT GLASS FLUTED ANTIQUE': 356,
#  'LAUNDRY 15C METAL SIGN': 356,
#  'SET 20 NAPKINS FAIRY CAKES DESIGN ': 356,
#  'ROBOT BIRTHDAY CARD': 355,
#  'FELTCRAFT CUSHION BUTTERFLY': 353,
#  'BUNDLE OF 3 ALPHABET EXERCISE BOOKS': 353,
#  'SET/10 PINK POLKADOT PARTY CANDLES': 353,
#  'PIGGY BANK RETROSPOT ': 353,
#  'AGED GLASS SILVER T-LIGHT HOLDER': 351,
#  'RED RETROSPOT ROUND CAKE TINS': 351,
#  'VINTAGE CHRISTMAS STOCKING ': 351,
#  'RETROSPOT LARGE MILK JUG': 351,
#  'WOODEN TREE CHRISTMAS SCANDINAVIAN': 350,
#  'ENGLISH ROSE NOTEBOOK A7 SIZE': 350,
#  'JUMBO BAG PAISLEY PARK': 349,
#  'PINK BABY BUNTING': 348,
#  'CLASSIC CAFE SUGAR DISPENSER': 348,
#  'BALLOONS  WRITING SET ': 348,
#  'DOUGHNUT LIP GLOSS ': 347,
#  'ROLL WRAP VINTAGE CHRISTMAS': 345,
#  'PLAYING CARDS KEEP CALM & CARRY ON': 344,
#  'PLACE SETTING WHITE HEART': 344,
#  'DELUXE SEWING KIT ': 344,
#  'POTTERING MUG': 343,
#  'REGENCY MILK JUG PINK ': 342,
#  '36 PENCILS TUBE RED RETROSPOT': 341,
#  'REGENCY SUGAR BOWL GREEN': 341,
#  'WATERING CAN BLUE ELEPHANT': 341,
#  "GIANT 50'S CHRISTMAS CRACKER": 340,
#  'PAPER BUNTING WHITE LACE': 339,
#  'PACK OF 20 SKULL PAPER NAPKINS': 339,
#  'FELTCRAFT DOLL MOLLY': 339,
#  'SET OF 3 HANGING OWLS OLLIE BEAK': 338,
#  'SET OF 3 WOODEN STOCKING DECORATION': 338,
#  'PINK POLKADOT BOWL': 338,
#  'RED RETROSPOT WRAP ': 338,
#  'SET OF 36 TEATIME PAPER DOILIES': 337,
#  'CLASSIC GLASS COOKIE JAR': 336,
#  'FRENCH ENAMEL CANDLEHOLDER': 336,
#  "6 GIFT TAGS 50'S CHRISTMAS ": 333,
#  'LUNCH BAG PAISLEY PARK  ': 333,
#  '6 GIFT TAGS VINTAGE CHRISTMAS ': 333,
#  'RETROSPOT PARTY BAG + STICKER SET': 332,
#  'BLUE POLKADOT CUP': 332,
#  'FELTCRAFT CHRISTMAS FAIRY': 332,
#  'CHRISTMAS LIGHTS 10 REINDEER': 331,
#  "POPPY'S PLAYHOUSE LIVINGROOM ": 331,
#  'EDWARDIAN PARASOL RED': 330,
#  'LANTERN CREAM GAZEBO ': 330,
#  'RIBBON REEL HEARTS DESIGN ': 329,
#  'HEART IVORY TRELLIS LARGE': 328,
#  '10 COLOUR SPACEBOY PEN': 327,
#  'IVORY HANGING DECORATION  HEART': 327,
#  'SILVER HANGING T-LIGHT HOLDER': 327,
#  'VINTAGE CREAM CAT FOOD CONTAINER': 326,
#  'BLUE POLKADOT BOWL': 326,
#  'PHOTO CUBE': 325,
#  'CHILDRENS CUTLERY RETROSPOT RED ': 324,
#  'FANCY FONT BIRTHDAY CARD, ': 324,
#  'WHITE METAL LANTERN': 323,
#  'LONDON BUS COFFEE MUG': 322,
#  'RIBBON REEL CHRISTMAS SOCK BAUBLE': 322,
#  'CHOCOLATE BOX RIBBONS ': 321,
#  'JAM JAR WITH GREEN LID': 320,
#  'TEA TIME OVEN GLOVE': 319,
#  "CHILDREN'S APRON DOLLY GIRL ": 319,
#  'MEMO BOARD COTTAGE DESIGN': 318,
#  'ROTATING LEAVES T-LIGHT HOLDER': 317,
#  'KEY FOB , BACK DOOR ': 317,
#  'CARD DOLLY GIRL ': 316,
#  'CHARLIE+LOLA PINK HOT WATER BOTTLE': 316,
#  'SET/20 STRAWBERRY PAPER NAPKINS ': 315,
#  'SET OF 3 WOODEN SLEIGH DECORATIONS': 315,
#  '3 HEARTS HANGING DECORATION RUSTIC': 315,
#  "BISCUIT TIN 50'S CHRISTMAS": 314,
#  'POTTING SHED TEA MUG': 314,
#  'REGENCY TEA PLATE PINK': 314,
#  'ROLL WRAP VINTAGE SPOT ': 313,
#  'PINK  POLKADOT CUP': 312,
#  'HEART FILIGREE DOVE  SMALL': 310,
#  'SET 6 PAPER TABLE LANTERN HEARTS ': 309,
#  'RED RETROSPOT PLATE ': 308,
#  'RED FLORAL FELTCRAFT SHOULDER BAG': 308,
#  'KITCHEN METAL SIGN': 308,
#  'RETROSPOT RED WASHING UP GLOVES': 308,
#  'WOODEN CROQUET GARDEN SET': 307,
#  'SET OF 3 WOODEN TREE DECORATIONS': 307,
#  'GROW A FLYTRAP OR SUNFLOWER IN TIN': 307,
#  'FELTCRAFT DOLL ROSIE': 305,
#  'FULL ENGLISH BREAKFAST PLATE': 305,
#  'FRENCH WC SIGN BLUE METAL': 305,
#  'WHITE WICKER STAR ': 305,
#  'BAG 125g SWIRLY MARBLES': 304,
#  'HANGING HEART MIRROR DECORATION ': 303,
#  'GIN AND TONIC MUG': 302,
#  'LARGE CERAMIC TOP STORAGE JAR': 301,
#  'PACK OF 12 RED RETROSPOT TISSUES ': 301,
#  'CHILDRENS CUTLERY DOLLY GIRL ': 301,
#  'SET OF 4 ENGLISH ROSE PLACEMATS': 301,
#  'GRAND CHOCOLATECANDLE': 301,
#  'JUMBO BAG CHARLIE AND LOLA TOYS': 301,
#  'SET OF 6 HERB TINS SKETCHBOOK': 300,
#  'PANTRY SCRUBBING BRUSH': 300,
#  'DOORSTOP RETROSPOT HEART': 300,
#  'RED GINGHAM ROSE JEWELLERY BOX': 300,
#  'ROUND SNACK BOXES SET OF 4 SKULLS': 298,
#  'CLASSIC METAL BIRDCAGE PLANT HOLDER': 298,
#  'SET OF 3 CAKE TINS SKETCHBOOK': 298,
#  'FOOD CONTAINER SET 3 LOVE HEART ': 297,
#  'IVORY WICKER HEART LARGE': 297,
#  'BREAD BIN DINER STYLE RED ': 296,
#  'SLEEPING CAT ERASERS': 295,
#  'WALL TIDY RETROSPOT ': 295,
#  'CHILDRENS CUTLERY POLKADOT BLUE': 295,
#  'FELTCRAFT PRINCESS OLIVIA DOLL': 293,
#  'BLACK/BLUE POLKADOT UMBRELLA': 293,
#  'VICTORIAN SEWING BOX SMALL ': 293,
#  'TOY TIDY SPACEBOY  ': 293,
#  'CREAM CUPID HEARTS COAT HANGER': 292,
#  'AIRLINE LOUNGE,METAL SIGN': 291,
#  'WOODEN HAPPY BIRTHDAY GARLAND': 291,
#  'JAZZ HEARTS PURSE NOTEBOOK': 291,
#  'DOORMAT HOME SWEET HOME BLUE ': 291,
#  'PEG BAG APPLES DESIGN': 291,
#  'COLOUR GLASS. STAR T-LIGHT HOLDER': 290,
#  'DOORMAT WELCOME PUPPIES': 290,
#  'CARD SUKI BIRTHDAY': 290,
#  'BIRD HOUSE HOT WATER BOTTLE': 289,
#  'DINOSAURS  WRITING SET ': 288,
#  'CARD CIRCUS PARADE': 288,
#  'WOOD STAMP SET THANK YOU': 288,
#  'SET OF 2 TEA TOWELS APPLE AND PEARS': 287,
#  'ROUND CAKE TIN VINTAGE RED': 286,
#  'SET 12 COLOUR PENCILS SPACEBOY ': 286,
#  'TRADITIONAL PICK UP STICKS GAME ': 286,
#  'FAMILY PHOTO FRAME CORNICE': 286,
#  'SET OF 4 KNICK KNACK TINS LONDON ': 286,
#  '15CM CHRISTMAS GLASS BALL 20 LIGHTS': 285,
#  'GIRAFFE WOODEN RULER': 285,
#  'HAPPY STENCIL CRAFT': 285,
#  'HOME SWEET HOME METAL SIGN ': 285,
#  'ANTIQUE GLASS DRESSING TABLE POT': 284,
#  'BUNDLE OF 3 RETRO NOTE BOOKS': 284,
#  'PARISIENNE KEY CABINET ': 284,
#  'BISCUIT TIN VINTAGE CHRISTMAS': 284,
#  'FELTCRAFT GIRL AMELIE KIT': 283,
#  'WATERING CAN PINK BUNNY': 283,
#  'TRAVEL CARD WALLET TRANSPORT': 283,
#  'VINTAGE LEAF MAGNETIC NOTEPAD': 282,
#  'SET OF 4 ENGLISH ROSE COASTERS': 282,
#  'CERAMIC CHERRY CAKE MONEY BANK': 281,
#  '12 PENCILS TALL TUBE RED RETROSPOT': 280,
#  'ICE CREAM SUNDAE LIP GLOSS': 279,
#  'RECYCLED ACAPULCO MAT TURQUOISE': 279,
#  'RIBBON REEL SNOWY VILLAGE': 279,
#  'QUEENS GUARD COFFEE MUG': 279,
#  'LIPSTICK PEN RED': 278,
#  'ZINC T-LIGHT HOLDER STARS SMALL': 278,
#  'GLASS JAR DAISY FRESH COTTON WOOL': 277,
#  'SET 2 TEA TOWELS I LOVE LONDON ': 277,
#  ' SET 2 TEA TOWELS I LOVE LONDON ': 277,
#  'PAPER BUNTING VINTAGE PAISLEY': 275,
#  'TREASURE ISLAND BOOK BOX': 275,
#  'SWALLOWS GREETING CARD': 275,
#  'CALENDAR PAPER CUT DESIGN': 275,
#  'PARISIENNE JEWELLERY DRAWER ': 275,
#  'COWBOYS AND INDIANS BIRTHDAY CARD ': 274,
#  'HEART DECORATION WITH PEARLS ': 274,
#  'PACK OF 12 WOODLAND TISSUES ': 274,
#  'ZINC WILLIE WINKIE  CANDLE STICK': 273,
#  'NO JUNK MAIL METAL SIGN': 273,
#  'COFFEE MUG APPLES DESIGN': 272,
#  'BATH BUILDING BLOCK WORD': 272,
#  'BOX OF VINTAGE ALPHABET BLOCKS': 272,
#  'TRAVEL CARD WALLET SUKI': 271,
#  'SINGLE ANTIQUE ROSE HOOK IVORY': 271,
#  'CHRISTMAS STAR WISH LIST CHALKBOARD': 271,
#  'BULL DOG BOTTLE OPENER': 270,
#  'BIRTHDAY CARD, RETRO SPOT': 270,
#  'PICTURE FRAME WOOD TRIPLE PORTRAIT': 270,
#  'SET OF 9 HEART SHAPED BALLOONS': 269,
#  'FELTCRAFT DOLL EMILY': 269,
#  'SMALL HANGING IVORY/RED WOOD BIRD': 269,
#  'RED METAL BOX TOP SECRET': 268,
#  'SMALL RED BABUSHKA NOTEBOOK ': 268,
#  'CARD PSYCHEDELIC APPLES': 268,
#  'RIBBON REEL CHRISTMAS PRESENT ': 268,
#  'CARD MOTORBIKE SANTA': 268,
#  'SET3 BOOK BOX GREEN GINGHAM FLOWER ': 268,
#  'VICTORIAN SEWING BOX MEDIUM': 267,
#  '36 PENCILS TUBE SKULLS': 267,
#  'MAGIC DRAWING SLATE SPACEBOY ': 267,
#  'FAIRY CAKE FLANNEL ASSORTED COLOUR': 266,
#  'COFFEE MUG CAT + BIRD DESIGN': 266,
#  'PINK FLORAL FELTCRAFT SHOULDER BAG': 265,
#  'VINTAGE DOILY JUMBO BAG RED ': 265,
#  'CHRISTMAS HANGING STAR WITH BELL': 265,
#  'PENNY FARTHING BIRTHDAY CARD': 264,
#  'SILVER BELLS TABLE DECORATION': 264,
#  'PINK HEART SHAPE EGG FRYING PAN': 262,
#  'CHRISTMAS TOILET ROLL': 262,
#  'TRADITIONAL NAUGHTS & CROSSES': 262,
#  'PINK DOUGHNUT TRINKET POT ': 262,
#  '12 PENCILS TALL TUBE SKULLS': 262,
#  'CHARLIE + LOLA RED HOT WATER BOTTLE': 261,
#  'ROCKING HORSE RED CHRISTMAS ': 261,
#  'RED RETROSPOT SUGAR JAM BOWL': 260,
#  'RED RETROSPOT OVEN GLOVE DOUBLE': 260,
#  'CHRISTMAS PUDDING TRINKET POT ': 260,
#  'PARISIENNE CURIO CABINET': 260,
#  'KINGS CHOICE TEA CADDY ': 260,
#  'MEDIUM CERAMIC TOP STORAGE JAR': 260,
#  'OWL DOORSTOP': 259,
#  '12 MESSAGE CARDS WITH ENVELOPES': 259,
#  'ICE CREAM PEN LIP GLOSS ': 259,
#  'PINK DRAWER KNOB ACRYLIC EDWARDIAN': 258,
#  'STRAWBERRY   PICNIC BAG': 258,
#  'SET OF 5 LUCKY CAT MAGNETS ': 258,
#  'MINIATURE ANTIQUE ROSE HOOK IVORY': 257,
#  'MAGNETS PACK OF 4 SWALLOWS': 257,
#  'VINTAGE DONKEY TAIL GAME ': 257,
#  'RED RETROSPOT BUTTER DISH': 257,
#  'SKULLS WRITING SET ': 256,
#  'PHOTO FRAME 3 CLASSIC HANGING': 256,
#  'HEART FILIGREE DOVE LARGE': 255,
#  'BUTTON BOX ': 255,
#  'RETROSPOT WOODEN HEART DECORATION': 254,
#  'SKETCHBOOK MAGNETIC SHOPPING LIST': 254,
#  '12 PENCILS TALL TUBE WOODLAND': 254,
#  'SMALL PURPLE BABUSHKA NOTEBOOK ': 253,
#  'GLASS APOTHECARY BOTTLE PERFUME': 253,
#  'TRIPLE HOOK ANTIQUE IVORY ROSE': 253,
#  'SET 6 PAPER TABLE LANTERN STARS ': 252,
#  'EMERGENCY FIRST AID TIN ': 252,
#  'BAG 250g SWIRLY MARBLES': 252,
#  'RAIN PONCHO RETROSPOT': 251,
#  'DECORATIVE WICKER HEART LARGE': 251,
#  'ADVENT CALENDAR GINGHAM SACK': 251,
#  'PANTRY ROLLING PIN': 250,
#  'GIN & TONIC DIET GREETING CARD ': 249,
#  'FOLKART ZINC HEART CHRISTMAS DEC': 249,
#  'CHILDRENS CUTLERY POLKADOT GREEN ': 249,
#  'WRAP ENGLISH ROSE ': 249,
#  'GLITTER BUTTERFLY CLIPS': 248,
#  'SCOTTIE DOGS BABY BIB': 248,
#  'SMALL CHOCOLATES PINK BOWL': 248,
#  'SMALL CERAMIC TOP STORAGE JAR ': 247,
#  'RED RETROSPOT CHILDRENS UMBRELLA': 247,
#  'ENCHANTED BIRD COATHANGER 5 HOOK': 247,
#  'CARD CHRISTMAS VILLAGE': 247,
#  'SET OF 36 DOILIES PANTRY DESIGN': 247,
#  'CHILDS BREAKFAST SET SPACEBOY ': 247,
#  'HERB MARKER BASIL': 246,
#  'BUBBLEGUM RING ASSORTED': 246,
#  'SET/10 BLUE POLKADOT PARTY CANDLES': 245,
#  'GUMBALL MAGAZINE RACK': 245,
#  'BOYS VINTAGE TIN SEASIDE BUCKET': 245,
#  'TRAVEL CARD WALLET I LOVE LONDON': 245,
#  'HERB MARKER MINT': 244,
#  'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN': 244,
#  'IVORY WICKER HEART MEDIUM': 244,
#  'BROCADE RING PURSE ': 244,
#  'GINGHAM HEART  DOORSTOP RED': 244,
#  'GARLAND WOODEN HAPPY EASTER': 244,
#  'HERB MARKER THYME': 243,
#  'PAPER BUNTING COLOURED LACE': 243,
#  'SET OF 4 JAM JAR MAGNETS': 243,
#  'HERB MARKER PARSLEY': 242,
#  'ROUND CONTAINER SET OF 5 RETROSPOT': 242,
#  'HERB MARKER ROSEMARY': 242,
#  'RED RETROSPOT TAPE': 242,
#  'BOX OF VINTAGE JIGSAW BLOCKS ': 241,
#  'FEATHER PEN,HOT PINK': 240,
#  'S/6 WOODEN SKITTLES IN COTTON BAG': 239,
#  'FINE WICKER HEART ': 239,
#  'SET 12 COLOUR PENCILS DOLLY GIRL ': 238,
#  'WRAP ALPHABET DESIGN': 238,
#  'KNEELING MAT HOUSEWORK  DESIGN': 238,
#  '3 TRADITIONAl BISCUIT CUTTERS  SET': 238,
#  'HOME SWEET HOME CUSHION COVER ': 237,
#  'ABC TREASURE BOOK BOX ': 237,
#  'GLASS  BEURRE DISH': 237,
#  'FUNKY DIVA PEN': 237,
#  'DOORMAT 3 SMILEY CATS': 236,
#  "CHILDREN'S SPACEBOY MUG": 236,
#  'METAL SIGN,CUPCAKE SINGLE HOOK': 236,
#  'SPACEBOY MINI BACKPACK': 236,
#  'MAGIC DRAWING SLATE DOLLY GIRL ': 236,
#  'PACK OF 12 SKULL TISSUES': 235,
#  'ANTIQUE GLASS PEDESTAL BOWL': 235,
#  'CARD PARTY GAMES ': 235,
#  'TRIPLE PHOTO FRAME CORNICE ': 235,
#  'GLASS BON BON JAR': 235,
#  'RED BABY BUNTING ': 235,
#  'GLASS JAR ENGLISH CONFECTIONERY': 234,
#  'HOME SWEET HOME HANGING HEART': 234,
#  'SET OF 3 BIRD LIGHT PINK FEATHER ': 233,
#  'POLKADOT RAIN HAT ': 233,
#  'APPLE BATH SPONGE': 232,
#  'CITRONELLA CANDLE GARDEN POT': 232,
#  'MINI CAKE STAND  HANGING STRAWBERY': 232,
#  'GIRLS VINTAGE TIN SEASIDE BUCKET': 232,
#  'WATERING CAN GREEN DINOSAUR': 232,
#  'RED METAL BEACH SPADE ': 231,
#  'SMALL RED RETROSPOT WINDMILL': 231,
#  'TRAVEL CARD WALLET UNION JACK': 231,
#  "POPPY'S PLAYHOUSE BATHROOM": 230,
#  'ROMANTIC PINKS RIBBONS ': 230,
#  'FANCY FONTS BIRTHDAY WRAP': 230,
#  'STRAWBERRY BATH SPONGE ': 230,
#  'AIRLINE BAG VINTAGE JET SET RED': 230,
#  'METAL SIGN EMPIRE TEA': 230,
#  'HEART DECORATION PAINTED ZINC ': 230,
#  'PACK OF 6 SANDCASTLE FLAGS ASSORTED': 230,
#  'SET OF 9 BLACK SKULL BALLOONS': 229,
#  'SET OF 6 3D KIT CARDS FOR KIDS': 229,
#  'LARGE CIRCULAR MIRROR MOBILE': 229,
#  '20 DOLLY PEGS RETROSPOT': 229,
#  'RIBBON REEL MAKING SNOWMEN ': 229,
#  'HANGING HEART WITH BELL': 228,
#  'MINI WOODEN HAPPY BIRTHDAY GARLAND': 228,
#  'TRAVEL CARD WALLET PANTRY': 228,
#  'STRAWBERRY FAIRY CAKE TEAPOT': 227,
#  'GLASS APOTHECARY BOTTLE TONIC': 227,
#  'SET 12 KIDS  WHITE CHALK STICKS': 227,
#  'SET OF 5 PANCAKE DAY MAGNETS': 227,
#  'PAINT YOUR OWN CANVAS SET': 226,
#  '6 RIBBONS EMPIRE  ': 226,
#  'PACK OF 12 SPACEBOY TISSUES': 226,
#  'DOORMAT AIRMAIL ': 226,
#  'CARD BIRTHDAY COWBOY': 226,
#  'JAZZ HEARTS ADDRESS BOOK': 226,
#  'HEART WOODEN CHRISTMAS DECORATION': 225,
#  'VINTAGE UNION JACK MEMOBOARD': 225,
#  'BLUE VINTAGE SPOT BEAKER': 225,
#  'TRAVEL CARD WALLET RETROSPOT': 225,
#  'DECORATIVE WICKER HEART MEDIUM': 224,
#  'GROW YOUR OWN BASIL IN ENAMEL MUG': 224,
#  'ANTIQUE SILVER TEA GLASS ETCHED': 224,
#  'FRENCH BATHROOM SIGN BLUE METAL': 224,
#  'BOX OF 6 CHRISTMAS CAKE DECORATIONS': 224,
#  'GLASS HEART T-LIGHT HOLDER ': 224,
#  'RETROSPOT CIGAR BOX MATCHES ': 223,
#  'SPACEBOY CHILDRENS CUP': 223,
#  'ROUND CAKE TIN VINTAGE GREEN': 223,
#  'WALL ART STOP FOR TEA ': 222,
#  'CAKE PLATE LOVEBIRD WHITE': 222,
#  'FOOT STOOL HOME SWEET HOME ': 222,
#  'HOLIDAY FUN LUDO': 222,
#  'STAR WOODEN CHRISTMAS DECORATION': 222,
#  'PACK OF 12 COLOURED PENCILS': 222,
#  'MINI LIGHTS WOODLAND MUSHROOMS': 221,
#  'SET/6 COLLAGE PAPER PLATES': 221,
#  'SET 3 PAPER VINTAGE CHICK PAPER EGG': 220,
#  'TREASURE TIN BUFFALO BILL ': 220,
#  'FILIGRIS HEART WITH BUTTERFLY': 220,
#  'CHRISTMAS LIGHTS 10 VINTAGE BAUBLES': 220,
#  'BLUE POLKADOT WRAP': 219,
#  'SMALL YELLOW BABUSHKA NOTEBOOK ': 219,
#  'VINTAGE CHRISTMAS GIFT SACK': 219,
#  'CHARLIE AND LOLA FIGURES TINS': 219,
#  'CARD I LOVE LONDON ': 219,
#  'DISCO BALL CHRISTMAS DECORATION': 218,
#  'VINTAGE DOILY DELUXE SEWING KIT ': 217,
#  'PENS ASSORTED FUNNY FACE': 217,
#  'ENGLISH ROSE GARDEN SECATEURS': 217,
#  'EMBOSSED GLASS TEALIGHT HOLDER': 217,
#  'DINOSAUR LUNCH BOX WITH CUTLERY': 217,
#  'OVEN MITT APPLES DESIGN': 217,
#  'PLAYING CARDS JUBILEE UNION JACK': 217,
#  'SET OF SALT AND PEPPER TOADSTOOLS': 216,
#  'BELLE JARDINIERE CUSHION COVER': 216,
#  'SPACEBOY CHILDRENS BOWL': 216,
#  'COFFEE MUG PEARS  DESIGN': 216,
#  'GAOLERS KEYS DECORATIVE GARDEN ': 216,
#  'LIPSTICK PEN FUSCHIA': 216,
#  'PACK OF 12 PINK PAISLEY TISSUES ': 216,
#  'KEY FOB , FRONT  DOOR ': 215,
#  'ENAMEL WASH BOWL CREAM': 215,
#  'RAINY LADIES BIRTHDAY CARD': 214,
#  "ROLL WRAP 50'S RED CHRISTMAS ": 214,
#  'JINGLE BELL HEART ANTIQUE SILVER': 214,
#  'VINTAGE KID DOLLY CARD ': 214,
#  'GLASS APOTHECARY BOTTLE ELIXIR': 214,
#  'SILVER STARS TABLE DECORATION': 214,
#  'PANTRY PASTRY BRUSH': 214,
#  'CHILDS BREAKFAST SET CIRCUS PARADE': 213,
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS': 213,
#  'PINK POLKADOT WRAP ': 213,
#  'BOHEMIAN COLLAGE STATIONERY SET': 213,
#  '3 TIER CAKE TIN GREEN AND CREAM': 212,
#  'HEADS AND TAILS SPORTING FUN': 212,
#  'CHILDRENS DOLLY GIRL MUG': 212,
#  'SET OF 2 WOODEN MARKET CRATES': 212,
#  'FRYING PAN UNION FLAG': 212,
#  'FRENCH BLUE METAL DOOR SIGN 1': 211,
#  'REGENCY SUGAR TONGS': 211,
#  'HERB MARKER CHIVES ': 211,
#  'SPACEBOY GIFT WRAP': 211,
#  'GYMKHANA TREASURE BOOK BOX': 211,
#  'MONSTERS STENCIL CRAFT': 211,
#  'UNION STRIPE WITH FRINGE  HAMMOCK': 210,
#  'DOORMAT TOPIARY': 210,
#  'ZINC HERB GARDEN CONTAINER': 209,
#  'METAL SIGN DROP YOUR PANTS': 209,
#  'ANTIQUE TALL SWIRLGLASS TRINKET POT': 209,
#  '3 DRAWER ANTIQUE WHITE WOOD CABINET': 209,
#  'BOTTLE BAG RETROSPOT ': 209,
#  'SET OF 5 MINI GROCERY MAGNETS': 209,
#  'SET OF 6 T-LIGHTS SANTA': 209,
#  'DRAWER KNOB CRACKLE GLAZE IVORY': 209,
#  'TOOTHPASTE TUBE PEN': 208,
#  'RED RETROSPOT TISSUE BOX': 208,
#  'DOORMAT UNION JACK GUNS AND ROSES': 208,
#  'MAKE YOUR OWN FLOWERPOWER CARD KIT': 208,
#  'GREEN POLKADOT BOWL': 207,
#  'BLACK KITCHEN SCALES': 207,
#  'ENAMEL WATERING CAN CREAM': 207,
#  'FLUTED ANTIQUE CANDLE HOLDER': 207,
#  'HANGING METAL STAR LANTERN': 207,
#  'LUNCH BAG SUKI  DESIGN ': 207,
#  'GOLD MINI TAPE MEASURE ': 207,
#  'PACK OF SIX LED TEA LIGHTS': 207,
#  'RECYCLED ACAPULCO MAT GREEN': 206,
#  'BEADED CRYSTAL HEART PINK ON STICK': 206,
#  'WHITE ROCKING HORSE HAND PAINTED': 206,
#  'BUNDLE OF 3 SCHOOL EXERCISE BOOKS  ': 205,
#  'GLITTER HANGING BUTTERFLY STRING': 205,
#  'CHRISTMAS RETROSPOT ANGEL WOOD': 205,
#  'STORAGE TIN VINTAGE DOILY ': 204,
#  'FUNKY WASHING UP GLOVES ASSORTED': 204,
#  '36 FOIL HEART CAKE CASES': 204,
#  '6 ROCKET BALLOONS ': 204,
#  'DOORMAT MULTICOLOUR STRIPE': 203,
#  'CHILDS BREAKFAST SET DOLLY GIRL ': 203,
#  '6 RIBBONS ELEGANT CHRISTMAS ': 203,
#  'VINTAGE BILLBOARD LOVE/HATE MUG': 202,
#  'IVORY GIANT GARDEN THERMOMETER': 202,
#  'RED VINTAGE SPOT BEAKER': 202,
#  'COFFEE MUG DOG + BALL DESIGN': 202,
#  'WOOD STAMP SET FLOWERS': 202,
#  'PICNIC BOXES SET OF 3 RETROSPOT ': 202,
#  'ANTIQUE ALL GLASS CANDLESTICK': 202,
#  'TRAVEL CARD WALLET SKULLS': 202,
#  'CERAMIC CAKE DESIGN SPOTTED MUG': 202,
#  "3 RAFFIA RIBBONS 50'S CHRISTMAS ": 201,
#  'CHRISTMAS GINGHAM STAR': 201,
#  'MAGIC DRAWING SLATE CIRCUS PARADE  ': 201,
#  'BIG DOUGHNUT FRIDGE MAGNETS': 201,
#  '6 RIBBONS SHIMMERING PINKS ': 201,
#  '3D TRADITIONAL CHRISTMAS STICKERS': 201,
#  'MINI CAKE STAND WITH HANGING CAKES': 200,
#  'BLUE POLKADOT PLATE ': 200,
#  'CHOCOLATE CALCULATOR': 200,
#  'CHRISTMAS RETROSPOT STAR WOOD': 199,
#  'TOADSTOOL MONEY BOX': 199,
#  'ROSE COTTAGE KEEPSAKE BOX ': 199,
#  'DOLLY GIRL CHILDRENS CUP': 199,
#  'CLASSIC CHROME BICYCLE BELL ': 199,
#  'S/4 PINK FLOWER CANDLES IN BOWL': 198,
#  'DOORMAT BLACK FLOCK ': 198,
#  'SET/6 PURPLE BUTTERFLY T-LIGHTS': 198,
#  'CHRISTMAS GINGHAM TREE': 198,
#  'CHRISTMAS TREE STAR DECORATION': 198,
#  'RIBBON REEL LACE DESIGN ': 197,
#  'SET OF 6 T-LIGHTS TOADSTOOLS': 197,
#  'GREEN CHRISTMAS TREE CARD HOLDER': 197,
#  'TRADTIONAL ALPHABET STAMP SET': 197,
#  'BLUE DRAWER KNOB ACRYLIC EDWARDIAN': 197,
#  'FRENCH BLUE METAL DOOR SIGN 2': 196,
#  'DOLLY GIRL CHILDRENS BOWL': 196,
#  'PACK OF 6 SKULL PAPER PLATES': 195,
#  'GREEN DRAWER KNOB ACRYLIC EDWARDIAN': 195,
#  'UNION JACK FLAG LUGGAGE TAG': 194,
#  'SET 12 COLOURING PENCILS DOILY': 194,
#  'WOOD STAMP SET BEST WISHES': 193,
#  'HEART WREATH DECORATION WITH BELL': 193,
#  'POLYESTER FILLER PAD 40x40cm': 193,
#  'PINK VINTAGE SPOT BEAKER': 193,
#  'DRAWER KNOB CERAMIC IVORY': 193,
#  'SET OF 4 KNICK KNACK TINS DOILEY ': 192,
#  'BAKING MOULD HEART MILK CHOCOLATE': 192,
#  'FRENCH TOILET SIGN BLUE METAL': 192,
#  'CUPCAKE LACE PAPER SET 6': 192,
#  'SET/4 RED MINI ROSE CANDLE IN BOWL': 192,
#  'KINGS CHOICE BISCUIT TIN': 192,
#  'PACK OF 12 PINK POLKADOT TISSUES': 191,
#  'EASTER CRAFT 4 CHICKS ': 191,
#  '36 PENCILS TUBE WOODLAND': 190,
#  'SET OF 4 KNICK KNACK TINS POPPIES': 190,
#  '3D VINTAGE CHRISTMAS STICKERS ': 190,
#  'GREEN VINTAGE SPOT BEAKER': 190,
#  'WELCOME  WOODEN BLOCK LETTERS': 190,
#  'BLACK HEART CARD HOLDER': 190,
#  'SET/6 PINK  BUTTERFLY T-LIGHTS': 190,
#  'SPACEBOY CHILDRENS EGG CUP': 189,
#  'ASSORTED BOTTLE TOP  MAGNETS ': 189,
#  'RECYCLED ACAPULCO MAT RED': 188,
#  'ALPHABET STENCIL CRAFT': 188,
#  'BLUE GIANT GARDEN THERMOMETER': 188,
#  'STAR DECORATION PAINTED ZINC ': 188,
#  'DECORATIVE CATS BATHROOM BOTTLE': 188,
#  'HOT WATER BOTTLE BABUSHKA ': 187,
#  'UNION JACK FLAG PASSPORT COVER ': 187,
#  'PACK 3 BOXES BIRD PANNETONE ': 187,
#  ' SPACEBOY BABY GIFT SET': 187,
#  'URBAN BLACK RIBBONS ': 187,
#  'PINK  POLKADOT PLATE ': 187,
#  'FELTCRAFT GIRL NICOLE KIT': 187,
#  'SPACEBOY BEAKER': 187,
#  'PIZZA PLATE IN BOX': 186,
#  'SWEETHEART WIRE MAGAZINE RACK': 186,
#  'SET 36 COLOUR PENCILS SPACEBOY ': 186,
#  'TEA FOR ONE POLKADOT': 186,
#  'CERAMIC STRAWBERRY DESIGN MUG': 185,
#  'VINTAGE  2 METER FOLDING RULER': 185,
#  'VICTORIAN  METAL POSTCARD SPRING': 185,
#  'OVERNIGHT BAG VINTAGE ROSE PAISLEY': 185,
#  'WOODLAND PARTY BAG + STICKER SET': 185,
#  'SET/6 COLLAGE PAPER CUPS': 185,
#  'BOUDOIR SQUARE TISSUE BOX': 184,
#  'HOME SWEET HOME BLACKBOARD': 183,
#  'DOORMAT RESPECTABLE HOUSE': 183,
#  "PACK OF 12 50'S CHRISTMAS TISSUES": 183,
#  'CHRISTMAS TREE HEART DECORATION': 183,
#  'WOOD STOCKING CHRISTMAS SCANDISPOT': 183,
#  'GLASS JAR DIGESTIVE BISCUITS': 183,
#  'ROCKING HORSE GREEN CHRISTMAS ': 182,
#  'FAIRY CAKES NOTEBOOK A7 SIZE': 182,
#  '3 TIER CAKE TIN RED AND CREAM': 182,
#  'MAN FLU METAL SIGN': 182,
#  'VICTORIAN SEWING BOX LARGE': 182,
#  'MUSICAL ZINC HEART DECORATION ': 182,
#  'BUFFALO BILL TREASURE BOOK BOX': 181,
#  'MISTLETOE HEART WREATH GREEN': 181,
#  'CHRISTMAS METAL TAGS ASSORTED ': 181,
#  'FEATHER PEN,COAL BLACK': 180,
#  '36 DOILIES VINTAGE CHRISTMAS': 180,
#  'VINTAGE BILLBOARD DRINK ME MUG': 180,
#  'PACK OF 6 PANNETONE GIFT BOXES': 180,
#  'PHARMACIE FIRST AID TIN': 180,
#  'DINOSAUR KEYRINGS ASSORTED': 179,
#  'CARD HOLDER GINGHAM HEART': 179,
#  'CERAMIC CAKE STAND + HANGING CAKES': 179,
#  'LARGE PURPLE BABUSHKA NOTEBOOK  ': 179,
#  'PACK OF 6 SKULL PAPER CUPS': 178,
#  ' DOLLY GIRL BEAKER': 178,
#  'CHILDRENS TOY COOKING UTENSIL SET': 178,
#  'NOVELTY BISCUITS CAKE STAND 3 TIER': 178,
#  'TRAVEL CARD WALLET FLOWER MEADOW': 178,
#  'CHRISTMAS RETROSPOT TREE WOOD': 178,
#  'SWALLOW WOODEN CHRISTMAS DECORATION': 178,
#  'BISCUIT TIN VINTAGE RED': 177,
#  'COTTON APRON PANTRY DESIGN': 177,
#  '12 PENCILS TALL TUBE POSY': 177,
#  'SAVE THE PLANET COTTON TOTE BAG': 177,
#  'MINI JIGSAW SPACEBOY': 177,
#  'MOODY GIRL DOOR HANGER ': 176,
#  'RED RETROSPOT TEA CUP AND SAUCER ': 176,
#  'MAKE YOUR OWN MONSOON CARD KIT': 176,
#  'WRAP RED APPLES ': 176,
#  'REGENCY TEA STRAINER': 176,
#  'WOOD STAMP SET HAPPY BIRTHDAY': 175,
#  'SKULLS  WATER TRANSFER TATTOOS ': 175,
#  'WALL ART BICYCLE SAFETY': 175,
#  'EDWARDIAN PARASOL PINK': 174,
#  'SMALL HEART FLOWERS HOOK ': 174,
#  'MAGIC DRAWING SLATE DINOSAUR': 174,
#  'SET 12 COLOUR PENCILS LOVE LONDON': 173,
#  'PINK OWL SOFT TOY': 173,
#  'BISCUITS SMALL BOWL LIGHT BLUE': 173,
#  'HEART SHAPED HOLLY WREATH': 173,
#  'SET 10 NIGHT OWL LIGHTS': 173,
#  'S/4 IVORY MINI ROSE CANDLE IN BOWL': 173,
#  '200 RED + WHITE BENDY STRAWS': 173,
#  'SEWING SUSAN 21 NEEDLE SET': 173,
#  'LE JARDIN BOTANIQUE CUSHION COVER': 172,
#  'SET/3 VANILLA SCENTED CANDLE IN BOX': 172,
#  'BEADED CRYSTAL HEART GREEN ON STICK': 172,
#  'CAMOUFLAGE LED TORCH': 171,
#  'SET OF 6 NATIVITY MAGNETS ': 171,
#  'WHITE JEWELLED HEART DECORATION': 171,
#  'ENAMEL COLANDER CREAM': 170,
#  'POLKADOT PEN': 170,
#  'ZINC T-LIGHT HOLDER STAR LARGE': 170,
#  'GENTLEMAN SHIRT REPAIR KIT ': 170,
#  'SWEETHEART 3 TIER CAKE STAND ': 170,
#  '3 ROSE MORRIS BOXED CANDLES': 170,
#  'VINTAGE UNION JACK APRON': 170,
#  'FIRST AID TIN': 170,
#  'RED GINGHAM TEDDY BEAR ': 170,
#  'PACK OF 12 STICKY BUNNIES': 170,
#  'CARD CAT AND TREE ': 170,
#  'AIRLINE BAG VINTAGE JET SET BROWN': 170,
#  'ASS FLORAL PRINT MULTI SCREWDRIVER': 170,
#  'RECYCLED PENCIL WITH RABBIT ERASER': 169,
#  'ANGEL DECORATION 3 BUTTONS ': 169,
#  'SET/4 SKULL BADGES': 169,
#  'FRENCH BLUE METAL DOOR SIGN 3': 169,
#  'FRENCH KITCHEN SIGN BLUE METAL': 169,
#  'PACK 3 BOXES CHRISTMAS PANNETONE': 168,
#  '3 HOOK HANGER MAGIC GARDEN': 168,
#  'EMPIRE TISSUE BOX': 168,
#  'ELEPHANT, BIRTHDAY CARD, ': 168,
#  'RED RETROSPOT MUG': 168,
#  'SET/6 TURQUOISE BUTTERFLY T-LIGHTS': 168,
#  'FRYING PAN RED RETROSPOT': 168,
#  'I CAN ONLY PLEASE ONE PERSON MUG': 168,
#  'PINK PARTY BAGS': 168,
#  'SET OF 6 T-LIGHTS SNOWMEN': 168,
#  'WHITE LOVEBIRD LANTERN': 167,
#  'RETRO COFFEE MUGS ASSORTED': 167,
#  ...}

# %%
counts = dataclean['Description'].value_counts()

percent = dataclean['Description'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

top_10 = pd.DataFrame({'counts': counts, '%': percent})

top_10.head(10)
# Out:
#                                     counts     %
# WHITE HANGING HEART T-LIGHT HOLDER    2357  0.4%
# REGENCY CAKESTAND 3 TIER              2189  0.4%
# JUMBO BAG RED RETROSPOT               2156  0.4%
# PARTY BUNTING                         1720  0.3%
# LUNCH BAG RED RETROSPOT               1625  0.3%
# ASSORTED COLOUR BIRD ORNAMENT         1488  0.3%
# SET OF 3 CAKE TINS PANTRY DESIGN      1465  0.3%
# PACK OF 72 RETROSPOT CAKE CASES       1367  0.3%
# LUNCH BAG  BLACK SKULL.               1323  0.2%
# NATURAL SLATE HEART CHALKBOARD        1272  0.2%

# %%
# Rank by percentage
plt.figure(figsize=(8,5))
dataclean['Description'].value_counts(normalize=True)[:10].plot(kind="bar", title="Percentage of Sales by Description").set(xlabel="Description", ylabel="Percentage")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #Analisis Market Basket

# %%
dataclean_basket = dataclean.groupby(["CustomerID","Description"]).size().reset_index(name="Count")

market_basket = (dataclean_basket.groupby(['CustomerID', 'Description'])['Count'].sum().unstack().reset_index().fillna(0).set_index('CustomerID'))
market_basket.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# CustomerID
# 12346.0                                 0.0                             0.0
# 12347.0                                 0.0                             0.0
# 12348.0                                 0.0                             0.0
# 12349.0                                 0.0                             0.0
# 12350.0                                 0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# CustomerID
# 12346.0                     0.0                           0.0
# 12347.0                     0.0                           0.0
# 12348.0                     0.0                           0.0
# 12349.0                     0.0                           0.0
# 12350.0                     0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# CustomerID
# 12346.0                               0.0                       0.0
# 12347.0                               0.0                       0.0
# 12348.0                               0.0                       0.0
# 12349.0                               0.0                       0.0
# 12350.0                               0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# CustomerID
# 12346.0                              0.0                       0.0
# 12347.0                              0.0                       0.0
# 12348.0                              0.0                       0.0
# 12349.0                              0.0                       0.0
# 12350.0                              0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# CustomerID                                                              ...
# 12346.0                                   0.0                      0.0  ...
# 12347.0                                   0.0                      0.0  ...
# 12348.0                                   0.0                      0.0  ...
# 12349.0                                   0.0                      0.0  ...
# 12350.0                                   0.0                      0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# CustomerID
# 12346.0                            0.0                        0.0
# 12347.0                            0.0                        0.0
# 12348.0                            0.0                        0.0
# 12349.0                            0.0                        0.0
# 12350.0                            0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# CustomerID
# 12346.0                                   0.0                             0.0
# 12347.0                                   0.0                             0.0
# 12348.0                                   0.0                             0.0
# 12349.0                                   0.0                             0.0
# 12350.0                                   0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# CustomerID
# 12346.0                                  0.0                              0.0
# 12347.0                                  0.0                              0.0
# 12348.0                                  0.0                              0.0
# 12349.0                                  0.0                              0.0
# 12350.0                                  0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# CustomerID
# 12346.0                                 0.0                               0.0
# 12347.0                                 0.0                               0.0
# 12348.0                                 0.0                               0.0
# 12349.0                                 0.0                               0.0
# 12350.0                                 0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# CustomerID
# 12346.0                              0.0                               0.0
# 12347.0                              0.0                               0.0
# 12348.0                              0.0                               0.0
# 12349.0                              0.0                               0.0
# 12350.0                              0.0                               0.0
#
# [5 rows x 3896 columns]

# %%
def encode_data(datapoint):
  if datapoint <= 0:
    return 0
  else:
    return 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Process the transformation into the market_basket dataset
market_basket = market_basket.applymap(encode_data)

# Check the result
market_basket.head()

market_basket.isna().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Description
#  4 PURPLE FLOCK DINNER CANDLES      0
#  50'S CHRISTMAS GIFT BAG LARGE      0
#  DOLLY GIRL BEAKER                  0
#  I LOVE LONDON MINI BACKPACK        0
#  I LOVE LONDON MINI RUCKSACK        0
#                                    ..
# ZINC T-LIGHT HOLDER STARS SMALL     0
# ZINC TOP  2 DOOR WOODEN SHELF       0
# ZINC WILLIE WINKIE  CANDLE STICK    0
# ZINC WIRE KITCHEN ORGANISER         0
# ZINC WIRE SWEETHEART LETTER TRAY    0
# Length: 3896, dtype: int64

# %% [markdown]
# #Algoritma Apriori

# %%
itemsets = apriori(market_basket, min_support= 0.04, use_colnames=True)
rules = association_rules(itemsets, metric='lift', min_threshold=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules.sort_values("lift", ascending = False, inplace = True)
rules.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            antecedents  \
# 390                       (POPPY'S PLAYHOUSE BEDROOM )
# 391                        (POPPY'S PLAYHOUSE KITCHEN)
# 30                       (BLUE HAPPY BIRTHDAY BUNTING)
# 31                       (PINK HAPPY BIRTHDAY BUNTING)
# 708  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 705  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...
# 713                   (PINK REGENCY TEACUP AND SAUCER)
# 700  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 706  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
# 707  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
#
#                                            consequents  antecedent support  \
# 390                        (POPPY'S PLAYHOUSE KITCHEN)            0.049405
# 391                       (POPPY'S PLAYHOUSE BEDROOM )            0.053294
# 30                       (PINK HAPPY BIRTHDAY BUNTING)            0.052150
# 31                       (BLUE HAPPY BIRTHDAY BUNTING)            0.054437
# 708  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...            0.062443
# 705  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.068618
# 713  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...            0.073422
# 700                   (PINK REGENCY TEACUP AND SAUCER)            0.059927
# 706  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...            0.059698
# 707  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...            0.074108
#
#      consequent support   support  confidence       lift  leverage  \
# 390            0.053294  0.041171    0.833333  15.636624  0.038538
# 391            0.049405  0.041171    0.772532  15.636624  0.038538
# 30             0.054437  0.044145    0.846491  15.549830  0.041306
# 31             0.052150  0.044145    0.810924  15.549830  0.041306
# 708            0.068618  0.051693    0.827839  12.064371  0.047408
# 705            0.062443  0.051693    0.753333  12.064371  0.047408
# 713            0.059927  0.051693    0.704050  11.748496  0.047293
# 700            0.073422  0.051693    0.862595  11.748496  0.047293
# 706            0.074108  0.051693    0.865900  11.684310  0.047268
# 707            0.059698  0.051693    0.697531  11.684310  0.047268
#
#      conviction  zhangs_metric
# 390    5.680238       0.984697
# 391    4.179030       0.988741
# 30     6.159665       0.987172
# 31     5.013073       0.989560
# 708    5.409939       0.978192
# 705    3.800907       0.984678
# 713    3.176458       0.987378
# 700    6.743430       0.973204
# 706    6.904509       0.972470
# 707    3.108753       0.987604

# %%
support = rules.support.to_numpy()
confidence = rules.confidence.to_numpy()

for i in range (len(support)):
    support[i] = support[i]
    confidence[i] = confidence[i]

plt.figure(figsize=(8,6))
plt.title('Association Rules')
plt.xlabel('support')
plt.ylabel('confidance')
sns.regplot(x=support, y=confidence, fit_reg=False)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #Rekomendasi

# %%
# Recommendation of Market Basket
rec_rules = rules[ (rules['lift'] > 1) & (rules['confidence'] >= 0.7) ]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cols_keep = {'antecedents':'item_1', 'consequents':'item_2', 'support':'support', 'confidence':'confidence', 'lift':'lift'}
cols_drop = ['antecedent support', 'consequent support', 'leverage', 'conviction']

recommendation_basket = pd.DataFrame(rec_rules).rename(columns= cols_keep).drop(columns=cols_drop).sort_values(by=['lift'], ascending = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
display(recommendation_basket)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                 item_1  \
# 390                       (POPPY'S PLAYHOUSE BEDROOM )
# 391                        (POPPY'S PLAYHOUSE KITCHEN)
# 30                       (BLUE HAPPY BIRTHDAY BUNTING)
# 31                       (PINK HAPPY BIRTHDAY BUNTING)
# 708  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# ..                                                 ...
# 401                         (REGENCY TEA PLATE ROSES )
# 381                   (PINK REGENCY TEACUP AND SAUCER)
# 474  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 59                   (GREEN REGENCY TEACUP AND SAUCER)
# 405                 (ROSES REGENCY TEACUP AND SAUCER )
#
#                                                 item_2   support  confidence  \
# 390                        (POPPY'S PLAYHOUSE KITCHEN)  0.041171    0.833333
# 391                       (POPPY'S PLAYHOUSE BEDROOM )  0.041171    0.772532
# 30                       (PINK HAPPY BIRTHDAY BUNTING)  0.044145    0.846491
# 31                       (BLUE HAPPY BIRTHDAY BUNTING)  0.044145    0.810924
# 708  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...  0.051693    0.827839
# ..                                                 ...       ...         ...
# 401                         (REGENCY CAKESTAND 3 TIER)  0.041857    0.813333
# 381                         (REGENCY CAKESTAND 3 TIER)  0.059698    0.813084
# 474                         (REGENCY CAKESTAND 3 TIER)  0.059927    0.808642
# 59                          (REGENCY CAKESTAND 3 TIER)  0.068618    0.769231
# 405                         (REGENCY CAKESTAND 3 TIER)  0.074108    0.758782
#
#           lift  zhangs_metric
# 390  15.636624       0.984697
# 391  15.636624       0.988741
# 30   15.549830       0.987172
# 31   15.549830       0.989560
# 708  12.064371       0.978192
# ..         ...            ...
# 401   4.008899       0.791277
# 381   4.007671       0.809946
# 474   3.985775       0.809066
# 59    3.791519       0.808363
# 405   3.740018       0.811919
#
# [145 rows x 6 columns]
